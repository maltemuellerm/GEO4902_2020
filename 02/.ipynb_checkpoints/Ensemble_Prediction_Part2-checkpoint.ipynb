# %% [markdown]
# # Ensemble prediction of a precipitation extreme event

# %%
# Activate the following in colab : 
#!pip3 install netCDF4
#!apt install proj-bin libproj-dev libgeos-dev
#!pip install https://github.com/matplotlib/basemap/archive/master.zip
    
import xarray as xr
# Out:
# /home/maltem/.local/lib/python3.6/site-packages/pandas/compat/_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Fill in the dates and hours for the exercise

# %%
year =  '2020'
day  =  '03'
month = '02'

hour_1  ='18'

url='https://thredds.met.no/thredds/dodsC/meps25epsarchive/' +year+'/'+month+'/'+day+'/meps_extracted_2_5km_'+year+month+day+'T'+hour_1+'Z.nc'
forecast_1 = xr.open_dataset(url)

# %%
forecast_1
# Out:
# <xarray.Dataset>
# Dimensions:                                                             (atmosphere_as_single_layer: 1, ensemble_member: 10, grib1_vLevel4: 1, grib1_vLevel7: 1, height0: 1, height1: 1, height2: 2, height3: 1, height_above_msl: 1, hybrid0: 2, hybrid1: 1, hybrid2: 65, isotherm_0C_level: 1, local_vertical_level_192: 1, pressure: 13, time: 67, top_of_atmosphere: 1, x: 889, y: 949)
# Coordinates:
#   * time                                                                (time) datetime64[ns] 2020-02-03T18:00:00 ... 2020-02-06T12:00:00
#   * ensemble_member                                                     (ensemble_member) int16 0 ... 9
#   * pressure                                                            (pressure) float32 50.0 ... 1000.0
#   * height_above_msl                                                    (height_above_msl) float32 0.0
#   * height0                                                             (height0) float32 0.0
#   * height1                                                             (height1) float32 2.0
#   * height2                                                             (height2) float32 80.0 120.0
#   * height3                                                             (height3) float32 10.0
#   * hybrid0                                                             (hybrid0) float64 0.9956 0.9985
#   * hybrid1                                                             (hybrid1) float64 0.9985
#   * hybrid2                                                             (hybrid2) float64 0.009869 ... 0.9985
#   * local_vertical_level_192                                            (local_vertical_level_192) float32 0.0
#   * isotherm_0C_level                                                   (isotherm_0C_level) int16 27315
#   * atmosphere_as_single_layer                                          (atmosphere_as_single_layer) int16 0
#   * grib1_vLevel4                                                       (grib1_vLevel4) float32 0.0
#   * grib1_vLevel7                                                       (grib1_vLevel7) float32 0.0
#   * top_of_atmosphere                                                   (top_of_atmosphere) int16 0
#   * x                                                                   (x) float32 -1022485.4 ... 1197514.6
#   * y                                                                   (y) float32 -1129330.6 ... 1240669.4
#     longitude                                                           (y, x) float64 ...
#     latitude                                                            (y, x) float64 ...
# Data variables:
#     forecast_reference_time                                             datetime64[ns] ...
#     p00                                                                 float64 ...
#     ap0                                                                 (hybrid0) float64 ...
#     b0                                                                  (hybrid0) float64 ...
#     p01                                                                 float64 ...
#     ap1                                                                 (hybrid1) float64 ...
#     b1                                                                  (hybrid1) float64 ...
#     p02                                                                 float64 ...
#     ap2                                                                 (hybrid2) float64 ...
#     b2                                                                  (hybrid2) float64 ...
#     projection_lambert                                                  int32 ...
#     air_temperature_0m                                                  (time, height0, ensemble_member, y, x) float32 ...
#     surface_geopotential                                                (time, height0, ensemble_member, y, x) float32 ...
#     liquid_water_content_of_surface_snow                                (time, height0, ensemble_member, y, x) float32 ...
#     x_wind_pl                                                           (time, pressure, ensemble_member, y, x) float64 ...
#     x_wind_z                                                            (time, height2, ensemble_member, y, x) float32 ...
#     x_wind_ml                                                           (time, hybrid0, ensemble_member, y, x) float64 ...
#     y_wind_ml                                                           (time, hybrid0, ensemble_member, y, x) float64 ...
#     air_temperature_ml                                                  (time, hybrid0, ensemble_member, y, x) float64 ...
#     altitude_of_0_degree_isotherm                                       (time, isotherm_0C_level, ensemble_member, y, x) float32 ...
#     downward_northward_momentum_flux_in_air                             (time, height0, ensemble_member, y, x) float32 ...
#     downward_eastward_momentum_flux_in_air                              (time, height0, ensemble_member, y, x) float32 ...
#     y_wind_pl                                                           (time, pressure, ensemble_member, y, x) float64 ...
#     y_wind_z                                                            (time, height2, ensemble_member, y, x) float32 ...
#     specific_humidity_ml                                                (time, hybrid0, ensemble_member, y, x) float64 ...
#     mass_fraction_of_cloud_condensed_water_in_air_ml                    (time, hybrid0, ensemble_member, y, x) float32 ...
#     mass_fraction_of_cloud_ice_in_air_ml                                (time, hybrid1, ensemble_member, y, x) float32 ...
#     integral_of_toa_net_downward_shortwave_flux_wrt_time                (time, top_of_atmosphere, ensemble_member, y, x) float32 ...
#     integral_of_surface_net_downward_shortwave_flux_wrt_time            (time, height0, ensemble_member, y, x) float32 ...
#     air_temperature_pl                                                  (time, pressure, ensemble_member, y, x) float64 ...
#     cloud_area_fraction_ml                                              (time, hybrid1, ensemble_member, y, x) float32 ...
#     mass_fraction_of_snow_in_air_ml                                     (time, hybrid1, ensemble_member, y, x) float32 ...
#     mass_fraction_of_rain_in_air_ml                                     (time, hybrid1, ensemble_member, y, x) float64 ...
#     mass_fraction_of_graupel_in_air_ml                                  (time, hybrid1, ensemble_member, y, x) float64 ...
#     geopotential_ml                                                     (time, hybrid2, ensemble_member, y, x) float64 ...
#     integral_of_toa_outgoing_longwave_flux_wrt_time                     (time, top_of_atmosphere, ensemble_member, y, x) float32 ...
#     integral_of_surface_net_downward_longwave_flux_wrt_time             (time, height0, ensemble_member, y, x) float32 ...
#     specific_humidity_pl                                                (time, pressure, ensemble_member, y, x) float64 ...
#     air_temperature_z                                                   (time, height2, ensemble_member, y, x) float32 ...
#     integral_of_surface_downward_latent_heat_evaporation_flux_wrt_time  (time, height0, ensemble_member, y, x) float32 ...
#     integral_of_surface_downward_latent_heat_sublimation_flux_wrt_time  (time, height0, ensemble_member, y, x) float32 ...
#     mass_fraction_of_cloud_condensed_water_in_air_pl                    (time, pressure, ensemble_member, y, x) float32 ...
#     water_evaporation_amount                                            (time, height0, ensemble_member, y, x) float32 ...
#     surface_snow_sublimation_amount_acc                                 (time, height0, ensemble_member, y, x) float32 ...
#     integral_of_surface_downward_sensible_heat_flux_wrt_time            (time, height0, ensemble_member, y, x) float32 ...
#     mass_fraction_of_cloud_ice_in_air_pl                                (time, pressure, ensemble_member, y, x) float64 ...
#     relative_humidity_z                                                 (time, height2, ensemble_member, y, x) float32 ...
#     integral_of_surface_downwelling_shortwave_flux_in_air_wrt_time      (time, height0, ensemble_member, y, x) float32 ...
#     integral_of_surface_downwelling_longwave_flux_in_air_wrt_time       (time, height0, ensemble_member, y, x) float32 ...
#     cloud_area_fraction_pl                                              (time, pressure, ensemble_member, y, x) float64 ...
#     integral_of_rainfall_amount_wrt_time                                (time, height0, ensemble_member, y, x) float32 ...
#     integral_of_snowfall_amount_wrt_time                                (time, height0, ensemble_member, y, x) float32 ...
#     mass_fraction_of_snow_in_air_pl                                     (time, pressure, ensemble_member, y, x) float32 ...
#     surface_air_pressure                                                (time, height0, ensemble_member, y, x) float32 ...
#     integral_of_graupelfall_amount_wrt_time                             (time, height0, ensemble_member, y, x) float32 ...
#     air_temperature_2m                                                  (time, height1, ensemble_member, y, x) float32 ...
#     mass_fraction_of_rain_in_air_pl                                     (time, pressure, ensemble_member, y, x) float64 ...
#     tropopause_air_temperature                                          (time, grib1_vLevel7, ensemble_member, y, x) float32 ...
#     altitude_of_0_degree_isotherm_from_above                            (time, grib1_vLevel4, ensemble_member, y, x) float32 ...
#     relative_humidity_2m                                                (time, height1, ensemble_member, y, x) float32 ...
#     specific_humidity_2m                                                (time, height1, ensemble_member, y, x) float32 ...
#     mass_fraction_of_graupel_in_air_pl                                  (time, pressure, ensemble_member, y, x) float64 ...
#     tropopause_air_pressure                                             (time, grib1_vLevel7, ensemble_member, y, x) float32 ...
#     x_wind_10m                                                          (time, height3, ensemble_member, y, x) float32 ...
#     y_wind_10m                                                          (time, height3, ensemble_member, y, x) float32 ...
#     cloud_area_fraction                                                 (time, height0, ensemble_member, y, x) float32 ...
#     turbulent_kinetic_energy_pl                                         (time, pressure, ensemble_member, y, x) float64 ...
#     altitude_of_isoTprimW_equal_0                                       (time, local_vertical_level_192, ensemble_member, y, x) float32 ...
#     high_type_cloud_area_fraction                                       (time, height0, ensemble_member, y, x) float32 ...
#     medium_type_cloud_area_fraction                                     (time, height0, ensemble_member, y, x) float32 ...
#     geopotential_pl                                                     (time, pressure, ensemble_member, y, x) float64 ...
#     specific_convective_available_potential_energy_old                  (time, height0, ensemble_member, y, x) float32 ...
#     low_type_cloud_area_fraction                                        (time, height0, ensemble_member, y, x) float32 ...
#     x_wind_gust_10m                                                     (time, height3, ensemble_member, y, x) float32 ...
#     relative_humidity_pl                                                (time, pressure, ensemble_member, y, x) float64 ...
#     atmosphere_convective_inhibition_old                                (time, height0, ensemble_member, y, x) float32 ...
#     y_wind_gust_10m                                                     (time, height3, ensemble_member, y, x) float32 ...
#     air_temperature_max                                                 (time, height1, ensemble_member, y, x) float32 ...
#     upward_air_velocity_pl                                              (time, pressure, ensemble_member, y, x) float64 ...
#     lifting_condensation_level                                          (time, height0, ensemble_member, y, x) float32 ...
#     air_temperature_min                                                 (time, height1, ensemble_member, y, x) float32 ...
#     atmosphere_boundary_layer_thickness                                 (time, height0, ensemble_member, y, x) float32 ...
#     ertel_potential_vorticity_pl                                        (time, pressure, ensemble_member, y, x) float64 ...
#     atmosphere_level_of_free_convection                                 (time, height0, ensemble_member, y, x) float32 ...
#     rainfall_amount                                                     (time, height0, ensemble_member, y, x) float32 ...
#     snowfall_amount                                                     (time, height0, ensemble_member, y, x) float32 ...
#     air_pressure_at_sea_level                                           (time, height_above_msl, ensemble_member, y, x) float32 ...
#     lwe_thickness_of_atmosphere_mass_content_of_water_vapor             (time, atmosphere_as_single_layer, ensemble_member, y, x) float32 ...
#     atmosphere_level_of_neutral_buoyancy                                (time, height0, ensemble_member, y, x) float32 ...
#     relative_humidity_ml                                                (time, hybrid0, ensemble_member, y, x) float64 ...
#     wind_direction                                                      (time, height3, ensemble_member, y, x) float32 ...
#     wind_speed                                                          (time, height3, ensemble_member, y, x) float32 ...
#     precipitation_amount_acc                                            (time, height0, ensemble_member, y, x) float32 ...
#     snowfall_amount_acc                                                 (time, height0, ensemble_member, y, x) float32 ...
#     wind_speed_of_gust                                                  (time, height3, ensemble_member, y, x) float32 ...
#     fog_area_fraction                                                   (time, height0, ensemble_member, y, x) float32 ...
# Attributes:
#     Conventions:                     CF-1.6
#     institution:                     Norwegian Meteorological Institute, MET ...
#     creator_url:                     met.no
#     summary:                         MEPS (MetCoOp-Ensemble Prediction System...
#     source:                          MEPS 2.5km
#     title:                           MEPS 2.5km
#     min_time:                        2020-02-03 18:00:00Z
#     max_time:                        2020-02-06
#     geospatial_lat_min:              51.0
#     geospatial_lat_max:              88.0
#     geospatial_lon_min:              -20.0
#     geospatial_lon_max:              80.0
#     references:                      unknown
#     license:                         https://www.met.no/en/free-meteorologica...
#     comment:                         none
#     history:                         2020-02-03 creation by fimex
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ### Find a specific point and plot the forecast.
# ###### Note AROME Arctic is on an irregular grid, so the xarray.sel functionality does not work:

# %%
import math
import numpy as np

def findindex(alat,alon,plat,plon):
    #finding identical location of pos plat, plon in array alat[],alon[]
    abslat = np.abs(alat-plat)
    abslon = np.abs(alon-plon)
    c = np.maximum(abslon,abslat)
    latlon_idx = np.argmin(c)
    x, y = np.where(c == np.min(c))
    #print(alats[x,y],alon[x,y])
    x=int(x)
    y=int(y)
   
    return (x,y)

# %%
[ix,jx] = findindex(forecast_1.latitude,forecast_1.longitude,59.9139,10.7522)

# %% [markdown]
# #### For example precipitation forecasts

# %%
memb=1
accpp_point_forecast_1 = forecast_1.precipitation_amount_acc[:,0,memb,ix,jx]

# %%
from matplotlib import pyplot as plt

plt.plot(forecast_1.time, accpp_point_forecast_1, '.-')
#plt.plot(forecast_2.time, tml_point_forecast_2, '.-')

plt.title("Longyearbyen Temperature Forecast")
plt.show()

# %% [markdown]
# ### Plot forecast on a map

# %%
from mpl_toolkits.basemap import Basemap

timestep_1=30
mlevel=0
memb=2

fig = plt.figure(figsize=(7.2,7.2)) #11.7
plt.subplots_adjust(left=0.05, right=0.95, top=0.90, bottom=0.05, wspace=0.15, hspace=0.05)
ax = plt.subplot(111)
m = Basemap(projection='stere', 
            boundinglat=60, lon_0=10, lat_0=60.4, 
            resolution='l', 
            llcrnrlat= 58.0, urcrnrlat=62.0, llcrnrlon=5.0, urcrnrlon=15.0)
 
m.drawcoastlines(color='#4D5D53'); m.fillcontinents(alpha=0.2)
parallels = np.arange(0.,90,10); m.drawparallels(parallels,labels=[1,1,1,0],fontsize=10)
meridians = np.arange(0.,360.,10); m.drawmeridians(meridians,labels=[0,0,0,1],latmax=80,fontsize=10)

x, y = m(np.array(forecast_1.longitude),np.array(forecast_1.latitude))               # compute map proj coordinates.

cs=m.contourf(x,y,np.array( forecast_1.precipitation_amount_acc[timestep_1,mlevel,memb,:,:]),cmap=plt.cm.coolwarm,extemd='max')

plt.title (np.datetime_as_string(forecast_1.time[timestep_1],unit='h'))
cbar = m.colorbar(cs,location='bottom',pad="5%")  
cbar.set_label('Accumulated precipitation in mm')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:21: UserWarning: The following kwargs were not used by contour: 'extemd'
